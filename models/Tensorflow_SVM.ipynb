# %%
import numpy as np
import pickle
from sklearn.decomposition import PCA
import tensorflow as tf

##################load data#####################
with open('dataset/preprocessed_data.pickle', 'rb') as f:
    data = pickle.load(f)
    
train_data = data['train_dataset']
test_data = data['test_dataset']

train_labels = data['train_labels']
test_labels = data['test_labels']

# in case you want to select a portion of the features
# start_index=0
# end_index=87
# train_data=train_data[:,start_index:end_index,:]
# test_data=test_data[:,start_index:end_index,:]


input_width = train_data.shape[1]
input_height = train_data.shape[2]

train_data = train_data.reshape((-1, input_width * input_height)).astype(np.float32)
test_data = test_data.reshape((-1, input_width * input_height)).astype(np.float32)

# print("Shape of training set after vectorization:")
# print(train_data.shape)

# print("Shape of test set after vectorization:")
# print(test_data.shape)

################## PCA #####################

print("Running PCA")

# run pca to reduce vector size to 900
pca = PCA(copy=True, iterated_power='auto', n_components=900, random_state=None,
          svd_solver='auto', tol=0.0, whiten=False)

pca.fit(train_data)

train_data = pca.transform(train_data)

test_data = pca.transform(test_data)

print("Shape of training set after pca:")
print(train_data.shape)

print("Shape of test set after pca:")
print(test_data.shape)

################## SVM using TensorFlow #####################

print("Training SVM")

# convert labels to one-hot encoding
train_labels = tf.one_hot(train_labels, depth=10)
test_labels = tf.one_hot(test_labels, depth=10)

# create a SVM model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(900,)),
    tf.keras.layers.Dense(10, use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(0.01))
])

# compile the model
model.compile(optimizer='adam', loss='hinge', metrics=['accuracy'])

# train the model
model.fit(train_data, train_labels, epochs=100, batch_size=128)

# evaluate the model on training set
train_loss, train_acc = model.evaluate(train_data, train_labels, verbose=2)
print(f"Train Accuracy: {train_acc*100:.2f}%")

# evaluate the model on test set
test_loss, test_acc = model.evaluate(test_data, test_labels, verbose=2)
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Running PCA
# Shape of training set after pca:
# (900, 900)
# Shape of test set after pca:
# (100, 900)
# Training SVM
# Epoch 1/100
# 8/8 [==============================] - 0s 4ms/step - loss: 6.5811 - accuracy: 0.1467
# Epoch 2/100
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9717 - accuracy: 0.1733
# Epoch 3/100
# 8/8 [==============================] - 0s 2ms/step - loss: 5.6199 - accuracy: 0.1878
# Epoch 4/100
# 8/8 [==============================] - 0s 2ms/step - loss: 5.3246 - accuracy: 0.2033
# Epoch 5/100
# 8/8 [==============================] - 0s 2ms/step - loss: 5.0636 - accuracy: 0.2267
# Epoch 6/100
# 8/8 [==============================] - 0s 3ms/step - loss: 4.8269 - accuracy: 0.2422
# Epoch 7/100
# 8/8 [==============================] - 0s 2ms/step - loss: 4.6097 - accuracy: 0.2700
# Epoch 8/100
# 8/8 [==============================] - 0s 2ms/step - loss: 4.4041 - accuracy: 0.2844
# Epoch 9/100
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2129 - accuracy: 0.3078
# Epoch 10/100
# 8/8 [==============================] - 0s 2ms/step - loss: 4.0381 - accuracy: 0.3389
# Epoch 11/100
# 8/8 [==============================] - 0s 4ms/step - loss: 3.8681 - accuracy: 0.3567
# Epoch 12/100
# 8/8 [==============================] - 0s 0s/step - loss: 3.7089 - accuracy: 0.3767
# Epoch 13/100
# 8/8 [==============================] - 0s 0s/step - loss: 3.5488 - accuracy: 0.3933
# Epoch 14/100
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4017 - accuracy: 0.4178
# Epoch 15/100
# 8/8 [==============================] - 0s 2ms/step - loss: 3.2555 - accuracy: 0.4333
# Epoch 16/100
# 8/8 [==============================] - 0s 2ms/step - loss: 3.1199 - accuracy: 0.4511
# Epoch 17/100
# 8/8 [==============================] - 0s 3ms/step - loss: 2.9918 - accuracy: 0.4667
# Epoch 18/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.8718 - accuracy: 0.4933
# Epoch 19/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7554 - accuracy: 0.5222
# Epoch 20/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6483 - accuracy: 0.5444
# Epoch 21/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5424 - accuracy: 0.5544
# Epoch 22/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4448 - accuracy: 0.5733
# Epoch 23/100
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3425 - accuracy: 0.5944
# Epoch 24/100
# 8/8 [==============================] - 0s 0s/step - loss: 2.2427 - accuracy: 0.6156
# Epoch 25/100
# 8/8 [==============================] - 0s 0s/step - loss: 2.1511 - accuracy: 0.6356
# Epoch 26/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0649 - accuracy: 0.6544
# Epoch 27/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9785 - accuracy: 0.6744
# Epoch 28/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8990 - accuracy: 0.6989
# Epoch 29/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8144 - accuracy: 0.7211
# Epoch 30/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7392 - accuracy: 0.7456
# Epoch 31/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6661 - accuracy: 0.7556
# Epoch 32/100
# 8/8 [==============================] - 0s 0s/step - loss: 1.5915 - accuracy: 0.7656
# Epoch 33/100
# 8/8 [==============================] - 0s 0s/step - loss: 1.5210 - accuracy: 0.7789
# Epoch 34/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4582 - accuracy: 0.7978
# Epoch 35/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3946 - accuracy: 0.8144
# Epoch 36/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3357 - accuracy: 0.8267
# Epoch 37/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2733 - accuracy: 0.8367
# Epoch 38/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2177 - accuracy: 0.8511
# Epoch 39/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1629 - accuracy: 0.8578
# Epoch 40/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1127 - accuracy: 0.8678
# Epoch 41/100
# 8/8 [==============================] - 0s 801us/step - loss: 1.0638 - accuracy: 0.8789
# Epoch 42/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0193 - accuracy: 0.8889
# Epoch 43/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.9760 - accuracy: 0.8956
# Epoch 44/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9283 - accuracy: 0.9011
# Epoch 45/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8810 - accuracy: 0.9044
# Epoch 46/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8317 - accuracy: 0.9144
# Epoch 47/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7974 - accuracy: 0.9222
# Epoch 48/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7608 - accuracy: 0.9256
# Epoch 49/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7229 - accuracy: 0.9300
# Epoch 50/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6822 - accuracy: 0.9356
# Epoch 51/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.9411
# Epoch 52/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6098 - accuracy: 0.9489
# Epoch 53/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.9522
# Epoch 54/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5464 - accuracy: 0.9556
# Epoch 55/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.9600
# Epoch 56/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.4959 - accuracy: 0.9644
# Epoch 57/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.4678 - accuracy: 0.9667
# Epoch 58/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.9700
# Epoch 59/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4125 - accuracy: 0.9733
# Epoch 60/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3855 - accuracy: 0.9756
# Epoch 61/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3661 - accuracy: 0.9822
# Epoch 62/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.9822
# Epoch 63/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.9833
# Epoch 64/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.9878
# Epoch 65/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.2877 - accuracy: 0.9900
# Epoch 66/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2722 - accuracy: 0.9911
# Epoch 67/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2571 - accuracy: 0.9922
# Epoch 68/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9933
# Epoch 69/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.9933
# Epoch 70/100
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2215 - accuracy: 0.9956
# Epoch 71/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9967
# Epoch 72/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1997 - accuracy: 0.9967
# Epoch 73/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.1869 - accuracy: 0.9978
# Epoch 74/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.1742 - accuracy: 0.9978
# Epoch 75/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9978
# Epoch 76/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 0.9978
# Epoch 77/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1490 - accuracy: 0.9978
# Epoch 78/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9978
# Epoch 79/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9978
# Epoch 80/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1327 - accuracy: 0.9978
# Epoch 81/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9978
# Epoch 82/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9989
# Epoch 83/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9989
# Epoch 84/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.1080 - accuracy: 0.9989
# Epoch 85/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9989
# Epoch 86/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.9989
# Epoch 87/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1004 - accuracy: 0.9989
# Epoch 88/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9989
# Epoch 89/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9989
# Epoch 90/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9989
# Epoch 91/100
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 0.9989
# Epoch 92/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.9989
# Epoch 93/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.9978
# Epoch 94/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9989
# Epoch 95/100
# 8/8 [==============================] - 0s 0s/step - loss: 0.0857 - accuracy: 0.9989
# Epoch 96/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9989
# Epoch 97/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9978
# Epoch 98/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9989
# Epoch 99/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0825 - accuracy: 0.9989
# Epoch 100/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 0.9989
# 29/29 - 0s - loss: 0.0816 - accuracy: 0.9989 - 113ms/epoch - 4ms/step
# Train Accuracy: 99.89%
# 4/4 - 0s - loss: 1.6682 - accuracy: 0.6300 - 31ms/epoch - 8ms/step
# Test Accuracy: 63.00%
